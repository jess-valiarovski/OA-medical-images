# %% [markdown]
# # Using Metadata to Improve Artifical Intelligance Medical Image Diagnostic Accuracy
# **Purpose and Background**
# Conduct a descriptive analysis of crowdsourced data extracted from user interaction with a mobile application where tasked to binarly (yes or no) identify abnormalities in medical images.
#
# Two user categories were differentiated: Medical experts hired to interact with the application; and crowd, anyone who downloaded and used the application.

# %% [markdown]
# ### Import datasets

# %%
import pandas as pd
import numpy as np
results = pd.read_csv('1345_customer_results.csv') #medical case results
admin = pd.read_csv('1345_admin_reads.csv') #raw individual read

# %% [markdown]
# ### Inspect Customer Results

# %%
results.dtypes
results = results.set_index('Case ID')

# %% [markdown]
# **Preliminary filtering for security purposes**

# %%
results = results.dropna(subset=['Origin']) 
results["Expert: Abnormal Votes"] = results["Origin"].str.extract(r'vote(\d)').astype(float)
results = results.drop(['Origin Created At','Origin','Content ID','URL'],axis=1)

# %%
results.head(2)
# Out:
#         Labeling State  Series  Series Index  Patch  Qualified Reads  \
# Case ID
# 5888087  Gold Standard     NaN           NaN    NaN                2
# 5888088  Gold Standard     NaN           NaN    NaN                3
#
#         Correct Label Majority Label  Difficulty  Agreement  \
# Case ID
# 5888087          'no'           'no'         0.0        1.0
# 5888088          'no'           'no'         0.0        1.0
#
#         First Choice Answer  First Choice Votes  First Choice Weight  \
# Case ID
# 5888087                'no'                   2                 1.54
# 5888088                'no'                   3                 2.34
#
#         Second Choice Answer  Second Choice Votes  Second Choice Weight  \
# Case ID
# 5888087                'yes'                    0                   0.0
# 5888088                'yes'                    0                   0.0
#
#          Internal Notes Comments  Explanation  Expert: Abnormal Votes
# Case ID
# 5888087             NaN       []          NaN                     2.0
# 5888088             NaN       []          NaN                     0.0

# %% [markdown]
# Any rows that did not have a string associated with expert votes in the URL were dropped (i.e. NA)

# %%
results = results.dropna(subset=["Expert: Abnormal Votes"])

# %% [markdown]
# **Inspect NaN Columns for Content**

# %%
results.loc[results['Series'].notna()| results['Series Index'].notna() | results['Patch'].notna() | results['Internal Notes'].notna() | results['Explanation'].notna()]
# Out:
# Empty DataFrame
# Columns: [Labeling State, Series, Series Index, Patch, Qualified Reads, Correct Label, Majority Label, Difficulty, Agreement, First Choice Answer, First Choice Votes, First Choice Weight, Second Choice Answer, Second Choice Votes, Second Choice Weight, Internal Notes, Comments, Explanation, Expert: Abnormal Votes]
# Index: []

# %% [markdown]
# Dataframe is empty; columns inspected will be dropped

# %%
results = results.drop(['Series','Series Index','Patch','Internal Notes','Explanation'],axis=1)

# %% [markdown]
# **Inspect Comments for Relevance**

# %%
results[results['Comments'] != '[]']
# Out:
#         Labeling State  Qualified Reads Correct Label Majority Label  \
# Case ID
# 5892332  Gold Standard                1          'no'           'no'
# 5894116  Gold Standard                5          'no'          'yes'
# 5896433  Gold Standard                3         'yes'           'no'
# 5899520  Gold Standard                2         'yes'           'no'
# 5900998  Gold Standard                2          'no'          'yes'
# 5901914  Gold Standard                6         'yes'           'no'
# 5902040  Gold Standard                2          'no'          'yes'
# 5904120  Gold Standard                1         'yes'           'no'
# 5904413  Gold Standard                3         'yes'           'no'
# 5904472  Gold Standard                3         'yes'          'yes'
# 5905734  Gold Standard                4         'yes'          'yes'
# 5908501  Gold Standard                5          'no'          'yes'
# 5909550  Gold Standard                3         'yes'          'yes'
# 5911442  Gold Standard                2          'no'           'no'
# 5913944  Gold Standard                3          'no'           'no'
# 5916678  Gold Standard                2         'yes'          'yes'
# 5916911  Gold Standard                4         'yes'           'no'
# 5916943  Gold Standard                4          'no'           'no'
# 5917576  Gold Standard                3          'no'          'yes'
#
#          Difficulty  Agreement First Choice Answer  First Choice Votes  \
# Case ID
# 5892332       0.000      1.000                'no'                   1
# 5894116       1.000      1.000               'yes'                   5
# 5896433       1.000      1.000                'no'                   3
# 5899520       1.000      1.000                'no'                   2
# 5900998       1.000      1.000               'yes'                   2
# 5901914       1.000      1.000                'no'                   6
# 5902040       1.000      1.000               'yes'                   2
# 5904120       1.000      1.000                'no'                   1
# 5904413       1.000      1.000                'no'                   3
# 5904472       0.333      0.667               'yes'                   2
# 5905734       0.500      0.500               'yes'                   2
# 5908501       1.000      1.000               'yes'                   5
# 5909550       0.000      1.000               'yes'                   3
# 5911442       0.500      0.500               'yes'                   1
# 5913944       0.333      0.667                'no'                   2
# 5916678       0.000      1.000               'yes'                   2
# 5916911       1.000      1.000                'no'                   4
# 5916943       0.250      0.750                'no'                   3
# 5917576       1.000      1.000               'yes'                   3
#
#          First Choice Weight Second Choice Answer  Second Choice Votes  \
# Case ID
# 5892332                 0.80                'yes'                    0
# 5894116                 4.00                 'no'                    0
# 5896433                 2.32                'yes'                    0
# 5899520                 1.58                'yes'                    0
# 5900998                 1.56                 'no'                    0
# 5901914                 4.72                'yes'                    0
# 5902040                 1.58                 'no'                    0
# 5904120                 0.78                'yes'                    0
# 5904413                 2.46                'yes'                    0
# 5904472                 1.58                 'no'                    1
# 5905734                 1.54                 'no'                    2
# 5908501                 4.14                 'no'                    0
# 5909550                 2.42                 'no'                    0
# 5911442                 0.88                 'no'                    1
# 5913944                 1.56                'yes'                    1
# 5916678                 1.56                 'no'                    0
# 5916911                 3.14                'yes'                    0
# 5916943                 2.48                'yes'                    1
# 5917576                 2.52                 'no'                    0
#
#          Second Choice Weight  \
# Case ID
# 5892332                  0.00
# 5894116                  0.00
# 5896433                  0.00
# 5899520                  0.00
# 5900998                  0.00
# 5901914                  0.00
# 5902040                  0.00
# 5904120                  0.00
# 5904413                  0.00
# 5904472                  0.78
# 5905734                  1.56
# 5908501                  0.00
# 5909550                  0.00
# 5911442                  0.87
# 5913944                  0.78
# 5916678                  0.00
# 5916911                  0.00
# 5916943                  0.76
# 5917576                  0.00
#
#                                                   Comments  \
# Case ID
# 5892332  ['There was rapid and spiky rates so why am I ...
# 5894116    ['Can someone explain why the answer is “no”?']
# 5896433                                             ['??']
# 5899520  ["i can't see any spike in this question so wh...
# 5900998    ['There is obviously a peak happened in there']
# 5901914                               ['No spike present']
# 5902040                                           ['How?']
# 5904120                                          ['How? ']
# 5904413                                      ['Multiple?']
# 5904472                                           [' Wtf']
# 5905734                                  ['Not a spike!!']
# 5908501            ['Why??', 'How is this “not” a spike?']
# 5909550                                            ['Why']
# 5911442                           ['The answer is wrong ']
# 5913944  ['Inconsistency ', 'Epileptic discharges seen ...
# 5916678          ['Where? Nothing meets criteria por IED']
# 5916911                                         ['Where?']
# 5916943                                              ['?']
# 5917576            ['The answer is wrong', 'The is wrong']
#
#          Expert: Abnormal Votes
# Case ID
# 5892332                     3.0
# 5894116                     0.0
# 5896433                     5.0
# 5899520                     5.0
# 5900998                     3.0
# 5901914                     5.0
# 5902040                     3.0
# 5904120                     6.0
# 5904413                     6.0
# 5904472                     5.0
# 5905734                     5.0
# 5908501                     3.0
# 5909550                     8.0
# 5911442                     3.0
# 5913944                     2.0
# 5916678                     5.0
# 5916911                     5.0
# 5916943                     3.0
# 5917576                     3.0

# %% [markdown]
# None of the comments seem relevant; comments column will be dropped

# %%
results = results.drop(['Comments'],axis=1)

# %% [markdown]
# There should only be 8 experts total; drop cases for expert count greater than 8

# %%
results = results[results["Expert: Abnormal Votes"] <= 8]

# %% [markdown]
# ### Important columns for analysis; original metadata
# Each row corresponds to a medical case
#
# **Identifiers:**
#
# Case ID: unique identifier will serve as index
#
# Labeling State: identifies whether a expert consensus has been achieved (yes=Gold Standard, no= In Progress)
#
# URL: Extracted out expert vote count within the URL
#
# **Reads and Annotations**
#
# Qualified Reads: total crowd vote count
#
# Expert: Abnormal Votes: number of experts who thought the case was abnormal
#
# (note, the total of experts voting is always 8)
#
# Correct Label: overall expert consensus
#
# {yes=case is abnormal, no=case is normal, NaN=no consensus}
#
# Majority Label: overall crowd consensus on each case
#
# **Measures of Confidence**
#
# Difficulty: Qualified Reads *without the Correct Label* divided by total Qualified Reads.
#
# Agreement: Qualified Reads *with the Majority Label* divided by total Qualified Reads.
#
# Nth Choice Answer: crowd answer (First Choice is the Majority Label)
#
# Nth Choice Votes: number of crowd votes per answer
#
# Nth Choice Weight:

# %% [markdown]
# ### Add Relevant Columns and Optimize Dataframe

# %% [markdown]
# #### Cluster cases categorically based on difficulty

# %%
bins=[0,0.2,0.4,0.6,0.8,1]
labels=['very easy','easy','moderate','challenging','very challenging']
results['Difficulty Category'] = pd.cut(results['Difficulty'],bins=bins,labels=labels,include_lowest=True)

# %% [markdown]
# #### Expert: Normal Votes:
# I subtracted the number of total experts by the known number of experts who voted the case as abnormal
#
# #### Expert Agreement:
# I divided the number of experts who voted the case as abnormal by the total number of experts to get the porportion of experts who agree that the case is abnormal.
#
# #### Error Rate:
# I extracted the indexes for each category and calculated the "error rate" for the experts who did not vote for the expert majority
#
# #### Consensus:
# I indiciated cases where there was unanimity between experts and crowd.

# %% [markdown]
# ### I will rename some of the original columns for clarity
#
#    #### {Original column --> Renamed Column}
#
#     Correct Label --> Expert Majority
#
#     Majority Label --> Crowd Majority
#
#     Difficulty --> Expert/Crowd Disagreement
#
#     Agreement --> Crowd Agreement

# %%
df = results
df["Expert Majority"] = results["Correct Label"]
df["Crowd Majority"] = results["Majority Label"]
df["Expert/Crowd Disagreement"] = results["Difficulty"] 
df["Crowd Agreement"] = results["Agreement"] 
df = df.drop(columns= ["Correct Label","Majority Label","Difficulty","Agreement"])

# %% [markdown]
# #### Expert/Crowd Disagreement
# is the porportion of crowd disagreeing with expert consensus (i.e. difficulty)
#
# #### Crowd Agreement
# is the porportion of crowd agreeing with crowd consensus (i.e. agreement)

# %% [markdown]
# #### Error rate of experts
# I extracted the indexes for each category and calculated the "error rate" for the experts who did not vote for the expert majority

# %%
expert_count = 8
df["Expert: Normal Votes"] = (expert_count - results["Expert: Abnormal Votes"])
df["Expert Agreement"] = df["Expert: Abnormal Votes"]/expert_count
df['Consensus'] = np.where(df['Expert Majority'] == df['Crowd Majority'],'yes','no')

# %%
EM_yes = df.index[df['Expert Majority'] == "'yes'"].tolist()

EM_no = df.index[df['Expert Majority'] == "'no'"].tolist()

df.loc[EM_yes,"Error Rate"]= df['Expert: Normal Votes'][EM_yes]/expert_count
df.loc[EM_no,"Error Rate"]= df['Expert: Abnormal Votes'][EM_no]/expert_count
#df.fillna('', inplace=True)
beg_index = list(df.columns).index('Expert: Abnormal Votes') #9
df.iloc[ : , 13:]
# Out:
#          Crowd Agreement  Expert: Normal Votes  Expert Agreement Consensus  \
# Case ID
# 5888087            1.000                   6.0             0.250       yes
# 5888088            1.000                   8.0             0.000       yes
# 5888089            1.000                   8.0             0.000       yes
# 5888090            1.000                   8.0             0.000       yes
# 5888091            0.571                   4.0             0.500        no
# ...                  ...                   ...               ...       ...
# 5918375            1.000                   6.0             0.250        no
# 5918376            0.667                   5.0             0.375        no
# 5918377            1.000                   4.0             0.500        no
# 5918378              NaN                   3.0             0.625        no
# 5918379            0.800                   3.0             0.625       yes
#
#          Error Rate
# Case ID
# 5888087       0.250
# 5888088       0.000
# 5888089       0.000
# 5888090       0.000
# 5888091         NaN
# ...             ...
# 5918375       0.250
# 5918376       0.375
# 5918377         NaN
# 5918378       0.375
# 5918379       0.375
#
# [27000 rows x 5 columns]

# %%
filt_df = df[df['Qualified Reads'] >= 5]
print(sum(df['Expert: Normal Votes']+df['Expert: Abnormal Votes'])-sum(df['Qualified Reads']))
print(sum(filt_df['Expert: Normal Votes']+filt_df['Expert: Abnormal Votes'])-sum(filt_df['Qualified Reads']))
# Out:
# 78020.0
# 16432.0

# %% [markdown]
# When we filtered the qualified reads to 5 or more, the disparity between expert and reader vote count significantly decreases (16,400 from 78,000);
# #### so, cases with ONLY 5  or more crowd reads will be further analyzed

# %%
filt_df
# Out:
#         Labeling State  Qualified Reads First Choice Answer  \
# Case ID
# 5888091    In Progress                7               'yes'
# 5888093  Gold Standard                6                'no'
# 5888099  Gold Standard                5                'no'
# 5888100  Gold Standard                7                'no'
# 5888102  Gold Standard                6                'no'
# ...                ...              ...                 ...
# 5918367  Gold Standard                5               'yes'
# 5918368  Gold Standard                8               'yes'
# 5918372  Gold Standard                7               'yes'
# 5918377    In Progress                6               'yes'
# 5918379  Gold Standard                5               'yes'
#
#          First Choice Votes  First Choice Weight Second Choice Answer  \
# Case ID
# 5888091                   4                 3.28                 'no'
# 5888093                   6                 4.94                'yes'
# 5888099                   5                 4.05                'yes'
# 5888100                   6                 4.92                'yes'
# 5888102                   6                 4.66                'yes'
# ...                     ...                  ...                  ...
# 5918367                   5                 3.98                 'no'
# 5918368                   8                 6.50                 'no'
# 5918372                   7                 5.78                 'no'
# 5918377                   6                 4.78                 'no'
# 5918379                   4                 3.20                 'no'
#
#          Second Choice Votes  Second Choice Weight  Expert: Abnormal Votes  \
# Case ID
# 5888091                    3                  2.32                     4.0
# 5888093                    0                  0.00                     0.0
# 5888099                    0                  0.00                     0.0
# 5888100                    1                  0.80                     0.0
# 5888102                    0                  0.00                     0.0
# ...                      ...                   ...                     ...
# 5918367                    0                  0.00                     3.0
# 5918368                    0                  0.00                     5.0
# 5918372                    0                  0.00                     6.0
# 5918377                    0                  0.00                     4.0
# 5918379                    1                  0.76                     5.0
#
#         Difficulty Category Expert Majority Crowd Majority  \
# Case ID
# 5888091                 NaN             NaN          'yes'
# 5888093           very easy            'no'           'no'
# 5888099           very easy            'no'           'no'
# 5888100           very easy            'no'           'no'
# 5888102           very easy            'no'           'no'
# ...                     ...             ...            ...
# 5918367    very challenging            'no'          'yes'
# 5918368           very easy           'yes'          'yes'
# 5918372           very easy           'yes'          'yes'
# 5918377                 NaN             NaN          'yes'
# 5918379           very easy           'yes'          'yes'
#
#          Expert/Crowd Disagreement  Crowd Agreement  Expert: Normal Votes  \
# Case ID
# 5888091                        NaN            0.571                   4.0
# 5888093                      0.000            1.000                   8.0
# 5888099                      0.000            1.000                   8.0
# 5888100                      0.143            0.857                   8.0
# 5888102                      0.000            1.000                   8.0
# ...                            ...              ...                   ...
# 5918367                      1.000            1.000                   5.0
# 5918368                      0.000            1.000                   3.0
# 5918372                      0.000            1.000                   2.0
# 5918377                        NaN            1.000                   4.0
# 5918379                      0.200            0.800                   3.0
#
#          Expert Agreement Consensus  Error Rate
# Case ID
# 5888091             0.500        no         NaN
# 5888093             0.000       yes       0.000
# 5888099             0.000       yes       0.000
# 5888100             0.000       yes       0.000
# 5888102             0.000       yes       0.000
# ...                   ...       ...         ...
# 5918367             0.375        no       0.375
# 5918368             0.625       yes       0.375
# 5918372             0.750       yes       0.250
# 5918377             0.500        no         NaN
# 5918379             0.625       yes       0.375
#
# [14887 rows x 18 columns]

# %% [markdown]
# # Exploratory Analysis

# %%
#%pip install jupyter-dash
import plotly.express as px
import plotly.io as pio
import plotly.figure_factory as ff
pio.renderers.default='notebook'
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
index = filt_df.index[filt_df['Crowd Majority']=="'no'"].tolist()
filt_df['Crowd Agreement'][index] -= 0.5
filt_df
# Out:
#         Labeling State  Qualified Reads First Choice Answer  \
# Case ID
# 5888091    In Progress                7               'yes'
# 5888093  Gold Standard                6                'no'
# 5888099  Gold Standard                5                'no'
# 5888100  Gold Standard                7                'no'
# 5888102  Gold Standard                6                'no'
# ...                ...              ...                 ...
# 5918367  Gold Standard                5               'yes'
# 5918368  Gold Standard                8               'yes'
# 5918372  Gold Standard                7               'yes'
# 5918377    In Progress                6               'yes'
# 5918379  Gold Standard                5               'yes'
#
#          First Choice Votes  First Choice Weight Second Choice Answer  \
# Case ID
# 5888091                   4                 3.28                 'no'
# 5888093                   6                 4.94                'yes'
# 5888099                   5                 4.05                'yes'
# 5888100                   6                 4.92                'yes'
# 5888102                   6                 4.66                'yes'
# ...                     ...                  ...                  ...
# 5918367                   5                 3.98                 'no'
# 5918368                   8                 6.50                 'no'
# 5918372                   7                 5.78                 'no'
# 5918377                   6                 4.78                 'no'
# 5918379                   4                 3.20                 'no'
#
#          Second Choice Votes  Second Choice Weight  Expert: Abnormal Votes  \
# Case ID
# 5888091                    3                  2.32                     4.0
# 5888093                    0                  0.00                     0.0
# 5888099                    0                  0.00                     0.0
# 5888100                    1                  0.80                     0.0
# 5888102                    0                  0.00                     0.0
# ...                      ...                   ...                     ...
# 5918367                    0                  0.00                     3.0
# 5918368                    0                  0.00                     5.0
# 5918372                    0                  0.00                     6.0
# 5918377                    0                  0.00                     4.0
# 5918379                    1                  0.76                     5.0
#
#         Difficulty Category Expert Majority Crowd Majority  \
# Case ID
# 5888091                 NaN             NaN          'yes'
# 5888093           very easy            'no'           'no'
# 5888099           very easy            'no'           'no'
# 5888100           very easy            'no'           'no'
# 5888102           very easy            'no'           'no'
# ...                     ...             ...            ...
# 5918367    very challenging            'no'          'yes'
# 5918368           very easy           'yes'          'yes'
# 5918372           very easy           'yes'          'yes'
# 5918377                 NaN             NaN          'yes'
# 5918379           very easy           'yes'          'yes'
#
#          Expert/Crowd Disagreement  Crowd Agreement  Expert: Normal Votes  \
# Case ID
# 5888091                        NaN            0.571                   4.0
# 5888093                      0.000            0.500                   8.0
# 5888099                      0.000            0.500                   8.0
# 5888100                      0.143            0.357                   8.0
# 5888102                      0.000            0.500                   8.0
# ...                            ...              ...                   ...
# 5918367                      1.000            1.000                   5.0
# 5918368                      0.000            1.000                   3.0
# 5918372                      0.000            1.000                   2.0
# 5918377                        NaN            1.000                   4.0
# 5918379                      0.200            0.800                   3.0
#
#          Expert Agreement Consensus  Error Rate
# Case ID
# 5888091             0.500        no         NaN
# 5888093             0.000       yes       0.000
# 5888099             0.000       yes       0.000
# 5888100             0.000       yes       0.000
# 5888102             0.000       yes       0.000
# ...                   ...       ...         ...
# 5918367             0.375        no       0.375
# 5918368             0.625       yes       0.375
# 5918372             0.750       yes       0.250
# 5918377             0.500        no         NaN
# 5918379             0.625       yes       0.375
#
# [14887 rows x 18 columns]

# %% [markdown]
# 0.5 was subtracted from the 'no' subsection of crowd agreements to match how expert agreement was calculated.

# %% [markdown]
# ## When experts and crowd disagree, what's the extent of their division?

# %%
consensus_no = filt_df.index[filt_df['Consensus']=='no'].tolist()
split_conses = (df[df["Expert Agreement"]==0.5])


fig2 = px.histogram(filt_df.loc[consensus_no], 
                    x='Expert Agreement',color='Expert Majority',
                    marginal='violin',color_discrete_map={"'yes'":'purple',"'no'":'red'}, 
                    labels={'x' : 'Agreement Ratio', 'y' : 'Count'}, text_auto=True
                   )
fig1 = px.histogram(filt_df.loc[consensus_no], 
                    x='Crowd Agreement',color='Crowd Majority',
                    marginal='violin', color_discrete_map={"'yes'":'green',"'no'":'yellow'},
                   text_auto=True)
fig3 = px.histogram(split_conses, x='Expert Agreement',color='Expert Majority', color_discrete_map={'nan':'blue'},
                   text_auto=True) #won't change color

fig1.update_xaxes(dtick=0.2)
fig1.update_traces(opacity=0.32)
fig2.update_layout(title_text='Overall Vote Distribution',
    title_x=0.5, showlegend=True,
    legend_title=None)
fig1.data[0].name="Crowd Majority: Yes"
fig2.data[0].name="Expert Majority: No"
fig1.data[2].name="Crowd Majority: No"
fig2.data[2].name="Expert Majority: Yes"
fig3.data[0].name="Expert Majority: NaN"
#########################
#NORMAL DISTRIBUTION: 
#https://stackoverflow.com/questions/63865209/plotly-how-to-show-both-a-normal-distribution-and-a-kernel-density-estimation-i

#group_labels = ['distplot']
#fig3 = ff.create_distplot(filt_df.loc[consensus_no], group_labels, curve_type = 'normal')
#normal_x = fig3.data[1]['x']
#normal_y = fig3.data[1]['y']

#fig2.add_traces(go.Scatter(x=normal_x, y=normal_y, mode = 'lines',
                        #  line = dict(color='rgba(0,255,0, 0.6)',
                                      #dash = 'dash'
                           #           width = 1),
                         # name = 'normal'
                        # ))
                    
############################                    
fig2.add_trace(fig1.data[0])
fig2.add_trace(fig1.data[1])
fig2.add_trace(fig1.data[2])
fig2.add_trace(fig1.data[3])
fig2.add_trace(fig3.data[0])
#fig1.show()

fig2.update_layout(barmode='overlay')
fig2.update_xaxes(dtick=0.2)
fig2.update_traces(opacity=0.32)
import plotly.graph_objects as go
fig2.add_shape(type="rect",x0=0.5,x1=0.55,y0=0,y1=750,line_width=1,line_dash='dot')
#fig2.add_trace(go.Scatter(filt_df.loc[consensus_no], x)
fig2.show()
fig2.update_layout(title_text='Vote Distribution: Normal',
    title_x=0.5, showlegend=True,
    legend_title=None)
fig2.update_xaxes(range=[-0.04,0.46])
fig2.update_yaxes(range=[0,850])
fig2.show()
fig2.update_xaxes(range=[0.55,1.04])
fig2.update_layout(title_text='Vote Distribution: Abnormal',
    title_x=0.5, showlegend=True,
    legend_title=None)
fig2.show()
# Out:
# <div>                            <div id="656b572d-9a17-4ffd-9d1a-d85a30449793" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("656b572d-9a17-4ffd-9d1a-d85a30449793")) {                    Plotly.newPlot(                        "656b572d-9a17-4ffd-9d1a-d85a30449793",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"
# %% [markdown]
# Axis range represents the extent of agreement within a group: 0.5 is split; 1 is full group agreement that the case is normal; 0 is full group agreement that the case is abnormal. Normal line distribution for each category shows that the crowd is more frequently unanimous in decision than experts are. This is evident because the curve peaks towards the middle of the graph for experts while for crowd the curve peaks towards the axis bounds, showing group agreement with the expert majority conclusion. **This shows that the crowd agrees with the expert majority more than experts agreeing with the expert majority**

# %% [markdown]
# ## Exploring in more detail what split and unanimous agreement look like

# %%
fig1 = px.histogram(filt_df, x='Crowd Agreement',color='Crowd Majority', color_discrete_map={"'yes'":'green',"'no'":'yellow'},
                   text_auto=True)

fig1.data[1].name="Crowd Majority: No"


fig1.data[0].name="Crowd Majority: Yes"


from plotly.subplots import make_subplots
fig = make_subplots(rows=1,cols=2)

fig.add_trace(fig1.data[1],row=1,col=1)
fig.update_xaxes(title_text='Crowd Majority: No',row=1,col=1)
fig.update_xaxes(range=[0.48,0.52])

fig.add_trace(fig1.data[0],row=1,col=2)

fig.update_xaxes(title_text='Crowd Majority: Yes',range=[0.48,0.52],row=1,col=2)

fig.update_yaxes(range=[0,3000])
fig.update_traces(opacity=0.6)
fig.update_layout(title_text="Number of Cases Where Crowd is Completely Split")
fig.add_shape(type="rect",x0=0.493,x1=0.507,y0=0,y1=2950,line_width=1,line_dash='dot', row=1,col=1)
fig.add_shape(type="rect",x0=0.493,x1=0.507,y0=0,y1=2950,line_width=1,line_dash='dot', row=1,col=2)
fig.show()

print(3003/(3003+186)*100)
print((743+116)/len(filt_df.index)*100)
# Out:
# <div>                            <div id="2e874cb4-a235-46a4-bb1a-b4763e602e3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e874cb4-a235-46a4-bb1a-b4763e602e3d")) {                    Plotly.newPlot(                        "2e874cb4-a235-46a4-bb1a-b4763e602e3d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Crowd Majority='no'<br>Crowd Agreement=%{x}<br>count=%{y}<extra></extra>","legendgroup":"'no'","marker":{"color":"yellow","pattern":{"shape":""}},"name":"Crowd Majority: No","offsetgroup":"'no'","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[0.5,0.5,0.357,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.357,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.30000000000000004,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.30000000000000004,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.30000000000000004,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.33299999999999996,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.30000000000000004,0.5,0.5,0.5,0.5,0.5,0.389,0.5,0.5,0.5,0.33299999999999996,0.5,0.30000000000000004,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.16700000000000004,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.33299999999999996,0.09999999999999998,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.09999999999999998,0.5,0.5,0.33299999999999996,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.30000000000000004,0.5,0.5,0.5,0.5,0.5,0.5,0.21399999999999997,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.33299999999999996,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.30000000000000004,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.33299999999999996,0.5,0.5,0.5,0.30000000000000004,0.5,0.09999999999999998,0.33299999999999996,0.357,0.09999999999999998,0.5,0.09999999999999998,0.07099999999999995,0.0,0.0,0.21399999999999997,0.5,0.05600000000000005,0.5,0.0,0.5,0.125,0.5,0.30000000000000004,0.5,0.09999999999999998,0.30000000000000004,0.25,0.0,0.30000000000000004,0.357,0.16700000000000004,0.09999999999999998,0.16700000000000004,0.5,0.5,0.09999999999999998,0.33299999999999996,0.375,0.5,0.5,0.5,0.5,0.33299999999999996,0.21399999999999997,0.5,0.07099999999999995,0.5,0.09999999999999998,0.16700000000000004,0.5,0.16700000000000004,0.0,0.30000000000000004,0.5,0.30000000000000004,0.16700000000000004,0.375,0.357,0.09999999999999998,0.5,0.07099999999999995,0.5,0.33299999999999996,0.09999999999999998,0.09999999999999998,0.0,0.09999999999999998,0.30000000000000004,0.16700000000000004,0.30000000000000004,0.5,0.16700000000000004,0.30000000000000004,0.16700000000000004,0.5,0.30000000000000004,0.16700000000000004,0.33299999999999996,0.0,0.16700000000000004,0.22699999999999998,0.33299999999999996,0.30000000000000004,0.125,0.21399999999999997,0.09999999999999998,0.21399999999999997,0.5,0.30000000000000004,0.25,0.09999999999999998,0.5,0.33299999999999996,0.09999999999999998,0.25,0.40900000000000003,0.19999999999999996,0.33299999999999996,0.0,0.5,0.5,0.5,0.30000000000000004,0.21399999999999997,0.16700000000000004,0.33299999999999996,0.09999999999999998,0.07099999999999995,0.5,0.0,0.5,0.09999999999999998,0.16700000000000004,0.5,0.30000000000000004,0.5,0.09999999999999998,0.16700000000000004,0.09999999999999998,0.30000000000000004,0.4,0.357,0.09999999999999998,0.357,0.16700000000000004,0.5 ...
# 94.16745061147695
# 5.770135017129039

# %% [markdown]
# Crowd is significantly more split on deciding what cases are abnormal; less dispute among crowd for choosing normal. 3003 cases failed to reach majority consensus where 94% of cases indecisive on whether the case is normal/healthy
#
# Additionally 743 cases were confidently labeled by crowd as abnormal (=1) and 116 as normal (=0),
# ### Only 5.77% of cases were able to be labeled by the crowd with full confidence

# %% [markdown]
# ## Are experts reliable? How frequently . Turns out, yes.

# %%
#fig = px.histogram(filt_df.loc[experts_split], x='Crowd Agreement',color='Crowd Majority',marginal='box')
#fig.show()


split_conses = filt_df.index[filt_df["Expert Agreement"]==0.5].tolist()
fig3 = px.histogram(filt_df[split_conses], x='Crowd Agreement',color='Crowd Majority')
fig3.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[208], line 6
#       1 #fig = px.histogram(filt_df.loc[experts_split], x='Crowd Agreement',color='Crowd Majority',marginal='box')
#       2 #fig.show()
#       5 split_conses = filt_df.index[filt_df["Expert Agreement"]==0.5].tolist()
# ----> 6 fig3 = px.histogram(filt_df[split_conses], x='Crowd Agreement',color='Crowd Majority')
#       7 fig3.show()
#
# File /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/lib/python3.11/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/lib/python3.11/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/lib/python3.11/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([5888091, 5888782, 5891822, 5891960, 5891979, 5892075, 5892132,\n            5892139, 5892162, 5892179,\n            ...\n            5918333, 5918334, 5918335, 5918337, 5918344, 5918358, 5918360,\n            5918363, 5918366, 5918377],\n           dtype='int64', length=2844)] are in the [columns]"

# %% [markdown]
# Seems uniform; which cases fall into the category? Are they the harder ones?

# %% [markdown]
# Make these into bubble charts to show porportion: https://plotly.com/python/bubble-charts/
